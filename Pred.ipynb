# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, models

from skimage import io, transform

import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
import os

from math import log

# %%
import import_ipynb
'''Local Improts'''
from Model_non_comp import RCNN
from Vocab_class import TermVocab
# Out:
# importing Jupyter notebook from Model_non_comp.ipynb
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
# Feature Shape: torch.Size([1, 25088])
# ['h', 'h', 'h', 'h', 'h', 'h', 'h', 'h', 'h', 'h']

# %%
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        #print('in transform init, rescalling')
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, image):
        #print('in transform call')
        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        img = transform.resize(image, (new_h, new_w))
        return img


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, image):
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        #print('in transform to tensor call')
        image = image.transpose((2, 0, 1))
        return image


# IMAGE_RESIZE = (256, 256)

# # For inception V3
# IMAGE_RESIZE = (299, 299)

#For VGG 11
IMAGE_RESIZE = (244, 244)

# Sequentially compose the transforms
img_transform = transforms.Compose([
    Rescale(IMAGE_RESIZE), ToTensor()])

# %%
class CaptionsPreprocessing:
    """Preprocess the captions, generate vocabulary and convert words to tensor tokens

    Args:
        captions_file_path (string): captions tsv file path
    """
    def __init__(self, captions_file_path):
        self.longest_seq = 0
        
        self.captions_file_path = captions_file_path

        # Read raw captions
        self.raw_captions_dict = self.read_raw_captions()

        # Preprocess captions
        self.captions_dict = self.process_captions()

        # Create vocabulary
        self.vocab = self.generate_vocabulary()
        

    def read_raw_captions(self):
        """
        Returns:
            Dictionary with raw captions list keyed by image ids (integers)
        """

        captions_dict = {}
        with open(self.captions_file_path, 'r', encoding='utf-8') as f:
            for img_caption_line in f.readlines():
                img_captions = img_caption_line.strip().split('\t')
                captions_dict[img_captions[0]] = img_captions[1]

        return captions_dict

    def process_captions(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """

        raw_captions_dict = self.raw_captions_dict
        longest_seq = 0
        start = ['<start>']
        end   = ['<end>']
        pos   = ['<pos>']
        # Do the preprocessing here
        for img_id in raw_captions_dict:
            term_list = raw_captions_dict[img_id].split()
            # Add nikki's code
            # term_list = 
            raw_captions_dict[img_id] = term_list
            if len(term_list)> longest_seq:
                longest_seq = len(term_list)
        
        self.longest_seq = longest_seq+2
        for img_id in raw_captions_dict:
            term_list = raw_captions_dict[img_id]
            term_list = start + term_list + end
            l = len(term_list)
            if l < longest_seq + 2:
                term_list = term_list[:-1]+pos*(longest_seq+2 - l)+ end
            raw_captions_dict[img_id] = term_list
                
        captions_dict = raw_captions_dict

        return captions_dict

    def generate_vocabulary(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """

        captions_dict = self.captions_dict

        # Generate the vocabulary
        vocab = TermVocab()
        #longest_term = 0
        #vocab = {}
        #index = 
        for img_id in captions_dict:
            contents = captions_dict[img_id]#.split()
            #print('for img-',img_id,":",contents)
            for term in contents:
                vocab.add_term(term)
        print('Generated vocab')
        
        return vocab

    def captions_transform(self, img_caption_list):
        """
        Use this function to generate tensor tokens for the text captions
        Args:
            img_caption_list: List of captions for a particular image
        """
        vocab = self.vocab

        # Generate tensors
        #print("caption transform called, with img caption list:", img_caption_list)
        #print(img_caption_list[0])
        img_cap_terms = img_caption_list
        op = torch.zeros(self.longest_seq)
        #print(self.longest_seq)
        for i in range(8):
            op[i] = vocab.to_index('<pos>')
        op[0] = vocab.to_index('<start>')
        op[-1] = vocab.to_index('<end>')
        
        #print('caption transform op:', op)
        return op
        # OLD:return torch.zeros(len(img_caption_list), 10)

# Set the captions tsv file path
CAPTIONS_FILE_PATH = '/media/harsh/Common/IITD/COL774-ML/ass4/Train_text.tsv'
captions_preprocessing_obj = CaptionsPreprocessing(CAPTIONS_FILE_PATH)
# Out:
# Generated vocab

# %%
class ImageCaptionsDataset(Dataset):

    def __init__(self, img_dir, image_paths, img_transform=None, captions_transform=None):
        """
        Args:
            img_dir (string): Directory with all the images.
            captions_dict: Dictionary with captions list keyed by image paths (strings)
            img_transform (callable, optional): Optional transform to be applied
                on the image sample.

            captions_transform: (callable, optional): Optional transform to be applied
                on the caption sample (list).
        """
        self.img_dir = img_dir
        self.captions_dict = image_paths
        self.img_transform = img_transform
        #print('img transform',img_transform)
        self.captions_transform = captions_transform

        self.image_ids = image_paths

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        img_name = self.image_ids[idx]
        #print('For IMG Id:', img_name)
        IMAGE_DIR = 'test_data/'
        image = io.imread(IMAGE_DIR+img_name)
        # captions = self.captions_dict[img_name]

        if self.img_transform:
            image = self.img_transform(image)

        if self.captions_transform:
            captions = self.captions_transform(None)
        # captions = ['start'] + 8*['pos'] + ['end']
        sample = {'image': image, 'captions': captions, 'image_id': img_name}

        return sample

# %%
IMAGE_DIR = 'test_data/'

image_paths = os.listdir(IMAGE_DIR)

# %%
def beam_search_decoder(data, k):
    sequences = [[list(), 0.0]]
    # walk over each step in sequence
    for row in data:
        all_candidates = list()
        # expand each current candidate
        for i in range(len(sequences)):
            seq, score = sequences[i]
            for j in range(len(row)):
                candidate = [seq + [j], score - log(row[j])]
                all_candidates.append(candidate)
        # order all candidates by score
        ordered = sorted(all_candidates, key=lambda tup:tup[1])
        # select k best
        sequences = ordered[:k]
    
    return sequences

# %%
embed_size = captions_preprocessing_obj.longest_seq
hidden_size = 20
vocab_size = captions_preprocessing_obj.vocab.vocab_length
layers = captions_preprocessing_obj.longest_seq

rcnn = RCNN(embed_size=embed_size,hidden_size=hidden_size, vocab_size=vocab_size, num_layers=layers)

# %%
def process_op(prediction):
    vocab = captions_preprocessing_obj.vocab
    caption = [vocab.to_term(term_idx) for term_idx in prediction]
    print(caption)
    return caption

def post_process_caption(caption_list):
    caption = ''
    for term in caption_list:
        if term == '<end>':
            break
        if term == '<start>' or term == '<pos>':
            continue
        caption += term + ' '
    return caption

# %%
continue_training = True
write_to_file = False
# Creating the Dataset
train_dataset = ImageCaptionsDataset(
    IMAGE_DIR, image_paths, img_transform=img_transform,
    captions_transform=captions_preprocessing_obj.captions_transform
)
# rcnn = None
# if continue_training == True:
#     rcnn = torch.load('rcnn.pth')
rcnn.load_state_dict(torch.load('model_weights_ncomp.pth'))
# Define your hyperparameters
NUMBER_OF_EPOCHS = 3
LEARNING_RATE = 1e-1
BATCH_SIZE = 1
NUM_WORKERS = 0 # Parallel threads for dataloading
continue_gtrain = True
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(rcnn.parameters(), lr=LEARNING_RATE)

#Other parameters
caption_length = captions_preprocessing_obj.longest_seq
vocab = captions_preprocessing_obj.vocab
vocab_size = vocab.vocab_length
# Creating the DataLoader for batching purposes
pred_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
import os
soft_m = nn.Softmax()
#print(rcnn)
rcnn.eval()
for batch_idx, sample in tqdm(enumerate(pred_loader)):
    #rcnn.zero_grad()
    #print(sample)
    image_batch, captions_batch, image_id = sample['image'], sample['captions'], sample['image_id']
    image_batch    = image_batch.float()
    captions_batch = captions_batch.long()
    lengths = [caption_length]*BATCH_SIZE
    # If GPU training required
    # image_batch, captions_batch = image_batch.cuda(), captions_batch.cuda()
    print('Image Ids:',image_id)
    
    # print(image_batch.shape, captions_batch.shape)
    # print(captions_batch[0].dtype)
    # print(image_batch.dtype)
    #print(image_batch[0])
    #output_captions = rcnn(image_batch, captions_batch, lengths)
    caption_list = rcnn.caption_image(image_batch, vocab.index2term, max_length=10)
    print(caption_list)
    caption = post_process_caption(caption_list)
    print(caption)
    
    with open('op.tsv','+a') as f:
        content = str(image_id) + '\t' + caption + '\n'
        f.write(content)
    
    ## Old and Depricated
    # output_captions = torch.reshape(output_captions, (BATCH_SIZE, -1, vocab_size))

    # print('output size:',output_captions.sha3.5720pe)
    # print('real caption size:',captions_batch.shape)
    # avg_loss = torch.tensor(0.0)
    # for b in range(BATCH_SIZE):
    #     # print('Target ind:',captions_batch[b])
    #     # print('Target seq:',process_op(captions_batch[b].tolist()))
    #     avg_loss += loss_function(output_captions[b], captions_batch[b])
    #     pred = beam_search_decoder(soft_m(output_captions[b]), 1)
    #     # print(len(pred[0][0]))
    #     # print('Prediction ind:',pred[0][0])
    #     # print('Prediction seq:',process_op(pred[0][0]))
# Out:
# 0it [00:00, ?it/s]
# Image Ids: ['test3021.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1122.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4393.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2338.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2959.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3112.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1498.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3639.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3847.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2315.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1157.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2390.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2305.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4062.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3451.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1528.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3850.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test827.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4201.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test840.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test652.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1181.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4103.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test25.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test338.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2085.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4413.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1804.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2635.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4688.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1773.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test596.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test322.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1566.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4086.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3806.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3251.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test479.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4669.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3321.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1251.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3063.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3318.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3732.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1685.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1633.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2742.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2483.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3817.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3608.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4927.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3445.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2012.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1631.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1465.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3268.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2652.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2537.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1456.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test229.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3644.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2228.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test394.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2711.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test785.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test498.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2909.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1572.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test535.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test196.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test884.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1561.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4571.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3356.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1344.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1216.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test503.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3372.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2937.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2308.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test644.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test152.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3166.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3902.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1667.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2445.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1292.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4998.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1026.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test365.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4466.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1219.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1998.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4339.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1336.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test190.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3311.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3461.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2031.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1538.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test702.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test743.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2612.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3630.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test786.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4083.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1504.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2155.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4353.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3481.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test527.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test779.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3600.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2421.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1927.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test703.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3026.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test609.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1947.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3017.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4468.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test131.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test900.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4840.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2722.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test809.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2216.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2548.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test621.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2842.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3111.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test211.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4129.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2709.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test313.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1531.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1090.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3802.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test335.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test718.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3033.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3432.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4149.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3809.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test349.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2058.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1105.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1049.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3964.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test259.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1801.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2779.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3401.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4409.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3371.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2447.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4441.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test978.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3624.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test375.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2183.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1285.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4415.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4505.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test330.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2029.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2162.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4491.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4937.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test453.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2710.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2586.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4306.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2479.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3900.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3143.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4600.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3915.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test722.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2454.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4336.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1728.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test140.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1600.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1352.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2300.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2559.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1317.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test653.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1079.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4252.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test308.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4916.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2324.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4209.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3910.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1951.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1462.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3546.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test360.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1000.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4902.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test29.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1763.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4917.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4854.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3271.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2387.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test243.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2464.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2778.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2332.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test482.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3873.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test28.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2626.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3627.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4549.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2809.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2694.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1088.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1915.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test421.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test116.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test19.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test914.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3178.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3275.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1570.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test10.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3851.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4806.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1343.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4190.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1766.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test202.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3521.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test12.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1220.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4040.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2783.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test967.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2134.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2268.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1316.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1186.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1942.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test713.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test178.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4626.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2599.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test953.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2414.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4598.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1036.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2971.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2353.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1101.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2870.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test541.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3219.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1092.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1983.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3185.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2460.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2372.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1175.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4373.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2703.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4621.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2967.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3366.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1623.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2139.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1491.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4568.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2102.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1937.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1016.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3787.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4130.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4724.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3035.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3340.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test850.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3791.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2628.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3337.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2476.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1594.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3152.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1470.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1201.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3507.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4490.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2137.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3485.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1774.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4494.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1921.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test305.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1302.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3672.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2554.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test889.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3496.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test15.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3218.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test195.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test410.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3223.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# ...
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3189.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1655.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1567.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4587.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2306.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test464.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1239.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2072.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2088.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3611.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4794.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test694.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test146.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1271.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3861.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1823.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4138.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3921.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4609.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3174.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1749.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4715.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4623.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4287.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4744.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1020.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test531.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test336.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2124.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2347.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3835.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4400.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3203.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4879.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2904.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test906.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2732.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4853.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test385.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4074.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1300.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3870.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3679.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test812.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1826.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4959.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3518.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2734.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1131.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test647.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3126.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4689.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2068.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2864.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1968.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3772.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3637.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2005.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1679.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test905.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3882.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3471.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4161.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3081.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2125.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4401.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4843.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2461.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1061.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test698.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3708.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2258.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1897.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1856.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4384.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test315.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2724.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2151.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1151.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test680.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1953.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3066.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test220.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4750.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1133.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test381.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4178.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4776.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test18.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test4472.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2912.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1885.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1894.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3848.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test708.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3449.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test270.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1732.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1604.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test268.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test1981.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2452.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test2679.jpg']
# Feature Shape: torch.Size([1, 25088])
# ['<start>', 'a', 'man', 'a', 'a', 'a', '<pos>', '<pos>', '<pos>', '<end>']
# a man a a a
# Image Ids: ['test3015.jpg']
